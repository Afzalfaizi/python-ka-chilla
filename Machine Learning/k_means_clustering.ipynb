# %% [markdown]
# # K-means Clustering

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# model
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# importing the data in features
x = df[['age', 'fare']]
x.age.fillna(value=x['age'].mean(),inplace=True)

# scaled data
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# perform clustering
model = KMeans(n_clusters=5)
model.fit(x_scaled)

# assign cluster labels to the  data
df['cluster'] = model.labels_
# Out:
# C:\Users\Afzaa\AppData\Local\Temp\ipykernel_4192\586811170.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.age.fillna(value=x['age'].mean(),inplace=True)
# c:\Users\Afzaa\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  cluster
# 0    man        True  NaN  Southampton    no  False        0
# 1  woman       False    C    Cherbourg   yes  False        4
# 2  woman       False  NaN  Southampton   yes   True        3
# 3  woman       False    C  Southampton   yes  False        3
# 4    man        True  NaN  Southampton    no   True        3

# %%
df['cluster'].nunique()
# Out:
# 5

# %%
x.head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
x.tail()
# Out:
#            age   fare
# 886  27.000000  13.00
# 887  19.000000  30.00
# 888  29.699118  23.45
# 889  26.000000  30.00
# 890  32.000000   7.75

# %%
x_scaled
# Out:
# array([[-0.53037664, -0.50244517],
#        [ 0.57183099,  0.78684529],
#        [-0.25482473, -0.48885426],
#        ...,
#        [        nan, -0.17626324],
#        [-0.25482473, -0.04438104],
#        [ 0.15850313, -0.49237783]])
